# %%
import numpy as np 
import matplotlib.pyplot as plt 

msg = "I'm sleepy but not sleeping."
print(msg)

x = np.linspace(0, 20, 100)
plt.plot(x, np.cos(x))
plt.show()
# Out:
# I'm sleepy but not sleeping.

# %%
y = (1,2,3,4,5)
y2 = 
print(y2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ea48d1afd565> in <module>
#       1 y = (1,2,3,4,5)
# ----> 2 y2 = y*y
#       3 print(y2)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
type(y)
# Out:
# tuple
